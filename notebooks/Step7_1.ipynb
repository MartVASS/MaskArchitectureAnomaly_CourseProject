# %% [markdown]
# <a href="https://colab.research.google.com/github/MartVASS/MaskArchitectureAnomaly_CourseProject/blob/main/notebooks/Step7_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

drive.mount('/content/drive')

# !pip install  ood_metrics
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ...

# %%
import os

# %cd /content/drive/MyDrive/FAIML_DANIELE/MaskArchitectureAnomaly_CourseProject
if not os.path.exists("data"):
    os.makedirs("data")

# !unzip -o "Anomaly_Validation_Datasets.zip" -d data/
# Out:
# /content/drive/MyDrive/FAIML_DANIELE/MaskArchitectureAnomaly_CourseProject
# Archive:  Anomaly_Validation_Datasets.zip
#   inflating: data/Validation_Dataset/.DS_Store
#   inflating: data/__MACOSX/Validation_Dataset/._.DS_Store
#   inflating: data/Validation_Dataset/RoadAnomaly21/.DS_Store
#   inflating: data/__MACOSX/Validation_Dataset/RoadAnomaly21/._.DS_Store
#   inflating: data/Validation_Dataset/RoadAnomaly/.DS_Store
#   inflating: data/__MACOSX/Validation_Dataset/RoadAnomaly/._.DS_Store
#   inflating: data/Validation_Dataset/RoadObsticle21/.DS_Store
#   inflating: data/__MACOSX/Validation_Dataset/RoadObsticle21/._.DS_Store
#   inflating: data/Validation_Dataset/fs_static/.DS_Store
#   inflating: data/__MACOSX/Validation_Dataset/fs_static/._.DS_Store
#   inflating: data/Validation_Dataset/FS_LostFound_full/.DS_Store
#   inflating: data/__MACOSX/Validation_Dataset/FS_LostFound_full/._.DS_Store
#   inflating: data/Validation_Dataset/RoadAnomaly21/images/8.png
# ...

# %%
# !python eval/evalAnomaly.py \
  --datasets RoadAnomaly RoadAnomaly21 fs_static LostFound RoadObsticle21 \
  --methods msp entropy maxlogit \
  --loadDir trained_models/
# Out:
# Loading model: trained_models/erfnet.py
# Loading weights: trained_models/erfnet_pretrained.pth
# Model and weights LOADED successfully
#
# ========== DATASET: RoadAnomaly ==========
#
# ---- METHOD: msp ----
# data/Validation_Dataset/RoadAnomaly/images/8.jpg
# data/Validation_Dataset/RoadAnomaly/images/48.jpg
# data/Validation_Dataset/RoadAnomaly/images/49.jpg
# data/Validation_Dataset/RoadAnomaly/images/59.jpg
# data/Validation_Dataset/RoadAnomaly/images/45.jpg
# data/Validation_Dataset/RoadAnomaly/images/58.jpg
# data/Validation_Dataset/RoadAnomaly/images/14.jpg
# data/Validation_Dataset/RoadAnomaly/images/9.jpg
# data/Validation_Dataset/RoadAnomaly/images/29.jpg
# data/Validation_Dataset/RoadAnomaly/images/28.jpg
# data/Validation_Dataset/RoadAnomaly/images/12.jpg
# data/Validation_Dataset/RoadAnomaly/images/17.jpg
# data/Validation_Dataset/RoadAnomaly/images/16.jpg
# data/Validation_Dataset/RoadAnomaly/images/15.jpg
# data/Validation_Dataset/RoadAnomaly/images/13.jpg
# ...

# %%
#!rm results.txt

#!python eval/evalAnomaly.py --input "data/Validation_Dataset/RoadAnomaly/images/*" --loadDir "trained_models/"

#!python eval/evalAnomaly.py --input "data/Validation_Dataset/RoadAnomaly21/images/*" --loadDir "trained_models/"

#!python eval/evalAnomaly.py --input "data/Validation_Dataset/RoadObsticle21/images/*" --loadDir "trained_models/"

#!python eval/evalAnomaly.py --input "data/Validation_Dataset/fs_static/images/*" --loadDir "trained_models/"

#!python eval/evalAnomaly.py --input "data/Validation_Dataset/FS_LostFound_full/images/*" --loadDir "trained_models/"
